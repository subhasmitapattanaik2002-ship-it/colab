# %% [markdown]
# <a href="https://colab.research.google.com/github/subhasmitapattanaik2002-ship-it/colab/blob/main/task_by_shiv_sir_in_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = ["subha", "kutun", "kiran", "swati", "Rohan"]   #1

print(students)
# Out:
# ['subha', 'kutun', 'kiran', 'swati', 'Rohan']

# %%
numbers = [10, 20, 30, 40, 50]   #2

print("First element:", numbers[0])
print("Last element:", numbers[-1])
# Out:
# First element: 10
# Last element: 50

# %%
#3
fruits = ["Apple", "Banana", "Mango"]

fruits.append("Orange")

print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
#4
subjects = ["Math", "English", "Science", "odia"]

subjects.insert(2, "AI")

print(subjects)
# Out:
# ['Math', 'English', 'AI', 'Science', 'odia']

# %%
#5
numbers = [10, 20, 30, 40, 50]
numbers.pop(2)
print(numbers)
# Out:
# [10, 20, 40, 50]

# %%
#6
numbers = [98, 65, 45, 55, 20]

print("Length of the list:", len(numbers))
print("Maximum value:", max(numbers))
print("Minimum value:", min(numbers))
print("Sum of all elements:", sum(numbers))
# Out:
# Length of the list: 5
# Maximum value: 98
# Minimum value: 20
# Sum of all elements: 283

# %%
#7
numbers = []

for i in range(5):
    num = int(input("Enter a number: "))
print("Complete List:", numbers)
# Out:
# Enter a number: 8
# Enter a number: 7
# Enter a number: 5
# Enter a number: 6
# Enter a number: 3
# Complete List: []

# %%
#8
cities = ["Mumbai", "Delhi", "Kolkata", "Chennai", "Bhubaneswar"]

if "Delhi" in cities:
    print("Delhi is present in the list")
else:
    print("Delhi is not present in the list")
# Out:
# Delhi is present in the list

# %%
#part B (tuple) #9
colors = ("Red", "Brown", "Green", "pink", "Black")

print("All Colors:")
for color in colors:
    print(color)
# Out:
# All Colors:
# Red
# Brown
# Green
# pink
# Black

# %%
#10
numbers = (10, 20, 30, 40, 50)

print("First element:", numbers[0])
print("Last element:", numbers[-1])
# Out:
# First element: 10
# Last element: 50

# %%
#11
students = ("situ", "litu", "situ", "Sital", "situ", "kutun")
count = students.count("situ")
print("situ appears", count, "times")
# Out:
# situ appears 3 times

# %%
#12
numbers = (12, 45, 7, 89, 23, 56)
print("Maximum value:", max(numbers))
print("Minimum value:", min(numbers))
print("Length of tuple:", len(numbers))
# Out:
# Maximum value: 89
# Minimum value: 7
# Length of tuple: 6

# %%
#13
t = (10, 20, 30, 40)

t[0] = 100
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7550/2778260801.py in <cell line: 0>()
#       2 t = (10, 20, 30, 40)
#       3
# ----> 4 t[0] = 100
#       5 print(t)
#       6
#
# TypeError: 'tuple' object does not support item assignment

# %%
#14
t = (1, 2, 3, 4, 5)

lst = list(t)

print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
#15
s = {10, 20, 30, 40, 50}
print(s)
# Out:
# {50, 20, 40, 10, 30}

# %%
#16
s = {10, 20, 30}

s.add(40)

print(s)
# Out:
# {40, 10, 20, 30}

# %%
#17
s = {10, 20, 30, 40}

s.remove(20)

print(s)
# Out:
# {40, 10, 30}

# %%
#18
s = {10, 20, 30, 30, 40, 40}

print(s)
# Out:
# {40, 10, 20, 30}

# %%
#19
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print("Union:", A | B)
print("Intersection:", A & B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}

# %%
#20
numbers = {10, 20, 30, 40, 50}

# Take input from the user
num = int(input("Enter a number: "))

# Check if the number exists
if num in numbers:
    print("Number exists in the set.")
else:
    print("Number does not exist in the set.")
# Out:
# Enter a number: 30
# Number exists in the set.

# %%
#21
person = {
    "Name": "Subhasmita",
    "Age": 20,
    "City": "Bhubaneswar"
}
print(person.values())

# %%
#22
                          # Create a student dictionary
student = {
    "name": "Situ",
    "age": 24
}
print(student)
# Out:
# {'name': 'Situ', 'age': 24}

# %%
#23
employee = {
    "Name": "Rahul",
    "Age": 30,
    "Department": "HR"
}

                                # Display all keys
print("Keys:", employee.keys())

                                  # Display all values
print("Values:", employee.values())
# Out:
# Keys: dict_keys(['Name', 'Age', 'Department'])
# Values: dict_values(['Rahul', 30, 'HR'])

# %%
#24
student = {
    "Name": "subha",
    "Marks": 75
}

                     # Update the value
student["Marks"] = 90
print(student)
# Out:
# {'Name': 'subha', 'Marks': 90}

# %%
#25
person = {
    "name": "subhasmita",
    "age": 24,
    "city": "Chennai"
}

                   # Remove the city key
person.pop("city")
print(person)
# Out:
# {'name': 'subhasmita', 'age': 24}

# %%
#26
students = {
    "usha": 85,
    "jitu": 90,
    "litu": 78,
    "rita": 88,
    "subha": 92
}
print(students.keys())
# Out:
# dict_keys(['usha', 'jitu', 'litu', 'rita', 'subha'])

# %%
#27
products = {
    "Pen": 10,
    "Book": 50,
    "Pencil": 5,
    "Bag": 500
}
item = input("Enter product name: ")
if item in products:
    print("Price:", products[item])
else:
    print("Product not found")
# Out:
# Enter product name: Book
# Price: 50

# %%
#28
student = {
    "name": "subha",
    "age": 24,
    "course": "Python"
}
key = input("Enter key: ")
if key in student:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Enter key: name
# Key exists

# %%
#29
students = ["litu", "kutun", "rani", "Priya", "situ"]
t = tuple(students)
print(t)
# Out:
# ('litu', 'kutun', 'rani', 'Priya', 'situ')

# %%
#30
# Create a dictionary
students = {
    "Rahul": 85,
    "Anu": 78,
    "Siva": 92,
    "Priya": 88,
    "Ravi": 75
}
for name, marks in students.items():
    if marks > 80:
        print(name, marks)
# Out:
# Rahul 85
# Siva 92
# Priya 88
