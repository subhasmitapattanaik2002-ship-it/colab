# %% [markdown]
# <a href="https://colab.research.google.com/github/subhasmitapattanaik2002-ship-it/colab/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("subha")
# Out:
# subha
